# %% [markdown]
# ### Prompt
#
# Financial analysts often need to consolidate data from various sources. This week's challenge focuses on using Alteryx functions in financial planning and analysis (FP&A) projects.
#
# The first dataset   includes sales information for various countries and business segments for the years 2022 and 2023, with the sales figures recorded in each country’s local currency. The second dataset provides the conversion rates from the countries’ currencies to   euros.
#
# Your first task is to create a final table that includes the segment, region, and total sales   in euros for both 2022 and 2023  . (Tip: Remove any columns where the sale price   is null.)
#
# For the second part of the challenge, calculate the year-over-year variation per segment (2022–2023) and identify the segments that experienced negative variations across all three regions: Europe, Asia Pacific (APAC), and the USA.

# %%
# importing library

import pandas as pd

import os 

import numpy as np

# %%
# importing data 

cwd = os.getcwd()

file_names = ['exchange_rates.csv','sales_figures.csv']

# creating function to join file paths

file_path_list = []

for x in file_names:
    
  file_path_list.append(os.path.join(cwd, x))

# %%
file_path_list
# Out:
# ['C:\\Users\\CharlesYi\\Jupyter Notebook\\Alteryx Challenges\\Challenge 449_Global Sales Analysis\\exchange_rates.csv',
#  'C:\\Users\\CharlesYi\\Jupyter Notebook\\Alteryx Challenges\\Challenge 449_Global Sales Analysis\\sales_figures.csv']

# %%
# creating function to import both data

dfs = {}

for x in file_path_list:
    
    file_name = os.path.basename(x)
    
    dfs[file_name] = pd.read_csv(x)

# %%
dfs
# Out:
# {'exchange_rates.csv':    Currency     EUR     USD     JPY     GBP     CHF     CAD     MAD    CNY  \
#  0       EUR  1.0000  1.0700  158.50  0.8600  0.9800  1.4700  11.240  7.460
#  1       USD  0.9300  1.0000  148.00  0.8000  0.9200  1.3700  10.500  6.970
#  2       JPY  0.0063  0.0068    1.00  0.0054  0.0062  0.0093   0.071  0.047
#  3       GBP  1.1700  1.2500  185.00  1.0000  1.1400  1.7100  13.160  8.730
#  4       CHF  1.0200  1.0900  161.00  0.8800  1.0000  1.5000  11.550  7.660
#  5       CAD  0.6800  0.7300  108.30  0.5800  0.6700  1.0000   7.700  5.100
#  6       MAD  0.0890  0.0950   14.05  0.0750  0.0870  0.1300   1.000  0.660
#  7       CNY  0.1300  0.1400   21.60  0.1100  0.1300  0.2000   1.520  1.000
#  8       THB  0.0260  0.0270    4.10  0.0220  0.0250  0.0370   0.290  0.190
#  9       ILS  0.2400  0.2600   37.80  0.2100  0.2400  0.3500   2.620  1.790
#  10      RUB  0.0098  0.0110    1.56  0.0084  0.0096  0.0140   0.110  0.073
#
#        THB    ILS     RUB
#  0   39.23  4.180  102.04
#  1   36.66  3.890   95.00
#  2    0.25  0.026    0.64
#  3   45.74  4.850  118.80
#  4   40.10  4.250  104.00
#  5   26.73  2.830   69.33
#  6    3.47  0.370    8.99
#  7    5.26  0.560   13.61
#  8    1.00  0.110    2.59
#  9    9.47  1.000   23.88
#  10   0.39  0.042    1.00  ,
#  'sales_figures.csv':      Region        Date           Segment Country Currency   Product  \
#  0      APAC  2022-02-01    Small Business   Japan      JPY       VTT
#  1      APAC  2022-02-01        Enterprise   China      CNY      Velo
#  2      APAC  2022-02-01        Enterprise   Japan      JPY      Velo
#  3      APAC  2022-02-01        Government   China      CNY   Montana
#  4      APAC  2022-02-01        Government   China      CNY  Amarilla
#  ...     ...         ...               ...     ...      ...       ...
#  2266    USA  2023-12-01    Small Business     USA      USD       VTT
#  2267    USA  2023-12-01        Government  Canada      CAD   Montana
#  2268    USA  2023-12-01        Enterprise  Canada      CAD      Velo
#  2269    USA  2023-12-01  Channel Partners     USA      USD  Amarilla
#  2270    USA  2023-12-01        Enterprise     USA      USD      Velo
#
#       Discount Band  Units Sold  Manufacturing Price  Sale Price  Gross Sales  \
#  0              Low      1778.0                260.0       350.0     622300.0
#  1           Medium      1802.0                 10.0        20.0      36040.0
#  2           Medium      2436.0                250.0       300.0     730800.0
#  3           Medium      1421.0                120.0        20.0      28420.0
#  4             High       808.0                250.0       300.0     242400.0
#  ...            ...         ...                  ...         ...          ...
#  2266        Medium       380.0                 10.0         7.0       2660.0
#  2267        Medium     30256.0                  3.0       125.0     302000.0
#  2268          High       623.0                250.0       350.0     218050.0
#  2269          High      2761.0                260.0      1200.0      33132.0
#  2270          High      2470.0                 10.0        15.0      37050.0
#
#        Discounts      Sales      COGS     Profit
#  0      24892.00   597408.0  462280.0  135128.00
#  1       1802.00    34238.0   18020.0   16218.00
#  2      43848.00   686952.0  609000.0   77952.00
#  3       1989.40    26430.6   14210.0   12220.60
#  4      19392.00   223008.0  202000.0   21008.00
#  ...         ...        ...       ...        ...
#  2266     292.60     2367.4    1900.0     467.40
#  2267   36240.00  3782000.0  289920.0  -24160.00
#  2268   26166.00   191884.0  161980.0   29904.00
#  2269    3975.84  3313200.0    8283.0   20873.16
#  2270    5187.00    31863.0   24700.0    7163.00
#
#  [2271 rows x 15 columns]}

# %%
df_exchange_rate = dfs['exchange_rates.csv']

df_exchange_rate.head()
# Out:
#   Currency     EUR     USD    JPY     GBP     CHF     CAD     MAD    CNY  \
# 0      EUR  1.0000  1.0700  158.5  0.8600  0.9800  1.4700  11.240  7.460
# 1      USD  0.9300  1.0000  148.0  0.8000  0.9200  1.3700  10.500  6.970
# 2      JPY  0.0063  0.0068    1.0  0.0054  0.0062  0.0093   0.071  0.047
# 3      GBP  1.1700  1.2500  185.0  1.0000  1.1400  1.7100  13.160  8.730
# 4      CHF  1.0200  1.0900  161.0  0.8800  1.0000  1.5000  11.550  7.660
#
#      THB    ILS     RUB
# 0  39.23  4.180  102.04
# 1  36.66  3.890   95.00
# 2   0.25  0.026    0.64
# 3  45.74  4.850  118.80
# 4  40.10  4.250  104.00

# %%
df_sales_figures = dfs['sales_figures.csv']

df_sales_figures.head(10)
# Out:
#   Region        Date           Segment Country Currency    Product  \
# 0   APAC  2022-02-01    Small Business   Japan      JPY        VTT
# 1   APAC  2022-02-01        Enterprise   China      CNY       Velo
# 2   APAC  2022-02-01        Enterprise   Japan      JPY       Velo
# 3   APAC  2022-02-01        Government   China      CNY    Montana
# 4   APAC  2022-02-01        Government   China      CNY   Amarilla
# 5   APAC  2022-02-01  Channel Partners   China      CNY  Carretera
# 6   APAC  2022-02-01        Government   Japan      JPY   Amarilla
# 7   APAC  2022-02-01        Government   Japan      JPY    Montana
# 8   APAC  2022-02-01        Government   Japan      JPY      Paseo
# 9   APAC  2022-03-01        Government   China      CNY        VTT
#
#   Discount Band  Units Sold  Manufacturing Price  Sale Price  Gross Sales  \
# 0           Low      1778.0                260.0       350.0     622300.0
# 1        Medium      1802.0                 10.0        20.0      36040.0
# 2        Medium      2436.0                250.0       300.0     730800.0
# 3        Medium      1421.0                120.0        20.0      28420.0
# 4          High       808.0                250.0       300.0     242400.0
# 5          High      1611.0                  5.0         7.0      11277.0
# 6          High      1916.0                120.0       125.0     239500.0
# 7          High      2015.0                260.0        12.0      24180.0
# 8          High      2438.0                120.0       125.0     304750.0
# 9           Low       727.0                 10.0       350.0     254450.0
#
#    Discounts      Sales      COGS     Profit
# 0   24892.00  597408.00  462280.0  135128.00
# 1    1802.00   34238.00   18020.0   16218.00
# 2   43848.00  686952.00  609000.0   77952.00
# 3    1989.40   26430.60   14210.0   12220.60
# 4   19392.00  223008.00  202000.0   21008.00
# 5    1014.93   10262.07    8055.0    2207.07
# 6   23950.00  215550.00  229920.0  -14370.00
# 7    3385.20   20794.80    6045.0   14749.80
# 8   45712.50  259037.50  292560.0  -33522.50
# 9   15267.00  239183.00  189020.0   50163.00

# %% [markdown]
# ### Task 1

# %%
# transposing exchange rates

df_exchange_transposed = pd.melt(df_exchange_rate, id_vars = 'Currency')

# filtering to variable EUR

currency_lookup = df_exchange_transposed[df_exchange_transposed['variable'] == 'EUR']

currency_lookup = currency_lookup[['Currency', 'value']]

currency_lookup
# Out:
#    Currency   value
# 0       EUR  1.0000
# 1       USD  0.9300
# 2       JPY  0.0063
# 3       GBP  1.1700
# 4       CHF  1.0200
# 5       CAD  0.6800
# 6       MAD  0.0890
# 7       CNY  0.1300
# 8       THB  0.0260
# 9       ILS  0.2400
# 10      RUB  0.0098

# %%
# joining currency lookup to data

df_merged = df_sales_figures.merge(currency_lookup, on = 'Currency')

df_merged
# Out:
#      Region        Date           Segment Country Currency   Product  \
# 0      APAC  2022-02-01    Small Business   Japan      JPY       VTT
# 1      APAC  2022-02-01        Enterprise   Japan      JPY      Velo
# 2      APAC  2022-02-01        Government   Japan      JPY  Amarilla
# 3      APAC  2022-02-01        Government   Japan      JPY   Montana
# 4      APAC  2022-02-01        Government   Japan      JPY     Paseo
# ...     ...         ...               ...     ...      ...       ...
# 2266    USA  2023-12-01        Government     USA      USD       VTT
# 2267    USA  2023-12-01        Government     USA      USD      Velo
# 2268    USA  2023-12-01    Small Business     USA      USD       VTT
# 2269    USA  2023-12-01  Channel Partners     USA      USD  Amarilla
# 2270    USA  2023-12-01        Enterprise     USA      USD      Velo
#
#      Discount Band  Units Sold  Manufacturing Price  Sale Price  Gross Sales  \
# 0              Low      1778.0                260.0       350.0     622300.0
# 1           Medium      2436.0                250.0       300.0     730800.0
# 2             High      1916.0                120.0       125.0     239500.0
# 3             High      2015.0                260.0        12.0      24180.0
# 4             High      2438.0                120.0       125.0     304750.0
# ...            ...         ...                  ...         ...          ...
# 2266           Low       736.0                120.0        20.0      14720.0
# 2267        Medium      1283.0                  5.0       300.0     384900.0
# 2268        Medium       380.0                 10.0         7.0       2660.0
# 2269          High      2761.0                260.0      1200.0      33132.0
# 2270          High      2470.0                 10.0        15.0      37050.0
#
#       Discounts      Sales      COGS     Profit   value
# 0      24892.00   597408.0  462280.0  135128.00  0.0063
# 1      43848.00   686952.0  609000.0   77952.00  0.0063
# 2      23950.00   215550.0  229920.0  -14370.00  0.0063
# 3       3385.20    20794.8    6045.0   14749.80  0.0063
# 4      45712.50   259037.5  292560.0  -33522.50  0.0063
# ...         ...        ...       ...        ...     ...
# 2266     588.80    14131.2    7360.0    6771.20  0.9300
# 2267   30792.00   354108.0  320750.0   33358.00  0.9300
# 2268     292.60     2367.4    1900.0     467.40  0.9300
# 2269    3975.84  3313200.0    8283.0   20873.16  0.9300
# 2270    5187.00    31863.0   24700.0    7163.00  0.9300
#
# [2271 rows x 16 columns]

# %%
# creating function to convert currencies

def currency_converter(df):
    
    cols = df.columns
    
    for col in cols:
        
        if pd.api.types.is_numeric_dtype(df[col]):
            df[col] = df[col] *  df['value']
        else:
            df[col] = df[col] 
    
    return df

# %%
# applying function

df_converted = currency_converter(df_merged)

df_converted.head()
# Out:
#   Region        Date         Segment Country Currency   Product Discount Band  \
# 0   APAC  2022-02-01  Small Business   Japan      JPY       VTT           Low
# 1   APAC  2022-02-01      Enterprise   Japan      JPY      Velo        Medium
# 2   APAC  2022-02-01      Government   Japan      JPY  Amarilla          High
# 3   APAC  2022-02-01      Government   Japan      JPY   Montana          High
# 4   APAC  2022-02-01      Government   Japan      JPY     Paseo          High
#
#    Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 0     11.2014                1.638      2.2050     3920.490  156.81960
# 1     15.3468                1.575      1.8900     4604.040  276.24240
# 2     12.0708                0.756      0.7875     1508.850  150.88500
# 3     12.6945                1.638      0.0756      152.334   21.32676
# 4     15.3594                0.756      0.7875     1919.925  287.98875
#
#         Sales       COGS     Profit    value
# 0  3763.67040  2912.3640  851.30640  0.00004
# 1  4327.79760  3836.7000  491.09760  0.00004
# 2  1357.96500  1448.4960  -90.53100  0.00004
# 3   131.00724    38.0835   92.92374  0.00004
# 4  1631.93625  1843.1280 -211.19175  0.00004

# %%
# checking date type

df_converted['Date'].dtype
# Out:
# dtype('O')

# %%
# converting to datetime

df_converted['Date'] = pd.to_datetime(df_converted['Date'])

df_converted['Date'].dtype # checking
# Out:
# dtype('<M8[ns]')

# %%
# extracting year from date

df_converted['year'] = df_converted['Date'].dt.year

df_converted.head()
# Out:
#   Region       Date         Segment Country Currency   Product Discount Band  \
# 0   APAC 2022-02-01  Small Business   Japan      JPY       VTT           Low
# 1   APAC 2022-02-01      Enterprise   Japan      JPY      Velo        Medium
# 2   APAC 2022-02-01      Government   Japan      JPY  Amarilla          High
# 3   APAC 2022-02-01      Government   Japan      JPY   Montana          High
# 4   APAC 2022-02-01      Government   Japan      JPY     Paseo          High
#
#    Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# 0     11.2014                1.638      2.2050     3920.490  156.81960
# 1     15.3468                1.575      1.8900     4604.040  276.24240
# 2     12.0708                0.756      0.7875     1508.850  150.88500
# 3     12.6945                1.638      0.0756      152.334   21.32676
# 4     15.3594                0.756      0.7875     1919.925  287.98875
#
#         Sales       COGS     Profit    value  year
# 0  3763.67040  2912.3640  851.30640  0.00004  2022
# 1  4327.79760  3836.7000  491.09760  0.00004  2022
# 2  1357.96500  1448.4960  -90.53100  0.00004  2022
# 3   131.00724    38.0835   92.92374  0.00004  2022
# 4  1631.93625  1843.1280 -211.19175  0.00004  2022

# %%
# aggregating total sales by region, segment, and year

df_sales = df_converted.groupby(['Region', 'Segment', 'year']).agg(total_sales = ('Sales', 'sum'))

df_sales.head()
# Out:
#                                 total_sales
# Region Segment          year
# APAC   Channel Partners 2022  296720.122271
#                         2023  354735.434574
#        Enterprise       2022  274177.242683
#                         2023  259736.397979
#        Government       2022  840175.462485

# %%
# resetting index

df_sales.reset_index(inplace=True)

# %%
# pivoting year

df_sales_pivot = pd.pivot(df_sales, index = ['Region', 'Segment'], columns = 'year', values = 'total_sales')

df_sales_pivot.reset_index(inplace = True)

df_sales_pivot.head()
# Out:
# year Region           Segment           2022          2023
# 0      APAC  Channel Partners  296720.122271  3.547354e+05
# 1      APAC        Enterprise  274177.242683  2.597364e+05
# 2      APAC        Government  840175.462485  1.089334e+06
# 3      APAC         Midmarket  617042.843926  5.634861e+05
# 4      APAC    Small Business  372555.686345  3.777840e+05

# %% [markdown]
# ### Task 2

# %%
df_sales
# Out:
#     Region           Segment  year   total_sales
# 0     APAC  Channel Partners  2022  2.967201e+05
# 1     APAC  Channel Partners  2023  3.547354e+05
# 2     APAC        Enterprise  2022  2.741772e+05
# 3     APAC        Enterprise  2023  2.597364e+05
# 4     APAC        Government  2022  8.401755e+05
# 5     APAC        Government  2023  1.089334e+06
# 6     APAC         Midmarket  2022  6.170428e+05
# 7     APAC         Midmarket  2023  5.634861e+05
# 8     APAC    Small Business  2022  3.725557e+05
# 9     APAC    Small Business  2023  3.777840e+05
# 10  Europe  Channel Partners  2022  1.747816e+07
# 11  Europe  Channel Partners  2023  1.652259e+07
# 12  Europe        Enterprise  2022  1.618712e+07
# 13  Europe        Enterprise  2023  1.073043e+07
# 14  Europe        Government  2022  7.297112e+07
# 15  Europe        Government  2023  5.411590e+07
# 16  Europe         Midmarket  2022  2.825850e+07
# 17  Europe         Midmarket  2023  1.858519e+07
# 18  Europe    Small Business  2022  1.139892e+07
# 19  Europe    Small Business  2023  1.619502e+07
# 20     USA  Channel Partners  2022  4.677241e+06
# 21     USA  Channel Partners  2023  5.581971e+06
# 22     USA        Enterprise  2022  2.901371e+06
# 23     USA        Enterprise  2023  2.101678e+06
# 24     USA        Government  2022  1.018704e+07
# 25     USA        Government  2023  1.164317e+07
# 26     USA         Midmarket  2022  6.037708e+06
# 27     USA         Midmarket  2023  5.433532e+06
# 28     USA    Small Business  2022  4.940531e+06
# 29     USA    Small Business  2023  4.690343e+06

# %%
# using shift to find yoy variation

def multi_row(group):
    
    group['prior_sales'] = group['total_sales'].shift(1)
    
    yoy_sales_list = []
    
    for index, row in group.iterrows():
    
        row['yoy_sales'] = ((row['total_sales'] - row['prior_sales'])/row['prior_sales'])*100
        
        yoy_sales = row['yoy_sales']
        
        yoy_sales_list.append(yoy_sales)
    
    group['yoy_variation'] = yoy_sales_list

    return group

# %%
# applying function

df_variation = df_sales.groupby(['Region', 'Segment']).apply(multi_row).reset_index(drop = True)

df_variation.head()
# Out:
#   Region           Segment  year    total_sales    prior_sales  yoy_variation
# 0   APAC  Channel Partners  2022  296720.122271            NaN            NaN
# 1   APAC  Channel Partners  2023  354735.434574  296720.122271      19.552200
# 2   APAC        Enterprise  2022  274177.242683            NaN            NaN
# 3   APAC        Enterprise  2023  259736.397979  274177.242683      -5.266974
# 4   APAC        Government  2022  840175.462485            NaN            NaN

# %%
# finding total variation by region and segment

df_variation = df_variation.groupby(['Region', 'Segment']).agg(total_variation = ('yoy_variation', 'sum'))

df_variation.reset_index(inplace = True)

# %%
# filtering out where variation is negative with query

df_queried = df_variation.query("total_variation<0")

df_queried
# Out:
#     Region           Segment  total_variation
# 1     APAC        Enterprise        -5.266974
# 3     APAC         Midmarket        -8.679589
# 5   Europe  Channel Partners        -5.467220
# 6   Europe        Enterprise       -33.710070
# 7   Europe        Government       -25.839295
# 8   Europe         Midmarket       -34.231508
# 11     USA        Enterprise       -27.562602
# 13     USA         Midmarket       -10.006724
# 14     USA    Small Business        -5.063989

# %%
# counting by segment

df_final = df_queried['Segment'].value_counts().reset_index()

df_final
# Out:
#             Segment  count
# 0        Enterprise      3
# 1         Midmarket      3
# 2  Channel Partners      1
# 3        Government      1
# 4    Small Business      1

# %%
# filtering to where count is greater than 3

df_final.query("count > 1")
# Out:
#       Segment  count
# 0  Enterprise      3
# 1   Midmarket      3
