# %% [markdown]
# ### Prompt
#
# The NBA is considered the world's premier basketball league due in large part to the tremendously talented players who dazzle fans every time out on the court. One of the highest honors for any player is to be named an All-Star. All-Stars are selected each year to recognize outstanding performance at each position. The All-Stars 2000-2016 file contains a list of players named All-Stars over that time period.
#
# You may notice that many of the league's 30 teams have at least one player selected over this time period. That is largely a result of the fact that regardless of whether they come from collegiate basketball teams or international club teams, players must enter the NBA Draft when entering the league. The draft is a system devised to spread talent across the league by giving teams who had poor seasons the best odds of signing the most promising new players coming into the league. In the current version of the draft, each of the 30 teams has one pick per round for 2 rounds. However, the league used to have fewer teams and more rounds in the draft. The Drafts Info file contains a listing of the number of picks in each round of the draft from 1984-2016.
#
# For this week's challenge, find the 3 latest drafted players to play in an All-Star game between 2000-2016. (Undrafted players are ineligible; draft position is overall pick number in a given draft)
#
# Data Source: https://www.kaggle.com/fmejia21/nba-all-star-game-20002016; https://www.nba.com/history/draft

# %%
# importing lib

import pandas as pd

import os

import re

# %%
# importing data

cwd = os.getcwd()

file_name = ['all_stars.csv', 'drafts.csv']

file_paths = []

for x in file_name:
    
    file_paths.append(os.path.join(cwd, x))
    
dfs = {}
    
for x in file_paths:
    
    basename = os.path.basename(x)
    
    dfs[basename] = (pd.read_csv(x))

df_allstars = dfs['all_stars.csv']

df_drafts = dfs['drafts.csv']

# %%
df_allstars.head()
# Out:
#    Year         Player Pos    HT   WT                   Team  \
# 0  2016  Stephen Curry   G   6-3  190  Golden State Warriors
# 1  2016   James Harden  SG   6-5  220        Houston Rockets
# 2  2016   Kevin Durant  SF   6-9  240  Golden State Warriors
# 3  2016  Kawhi Leonard   F   6-7  230      San Antonio Spurs
# 4  2016  Anthony Davis  PF  6-11  253   New Orleans Pelicans
#
#                         Selection Type    NBA Draft Status    Nationality
# 0  Western All-Star Fan Vote Selection   2009 Rnd 1 Pick 7  United States
# 1  Western All-Star Fan Vote Selection   2009 Rnd 1 Pick 3  United States
# 2  Western All-Star Fan Vote Selection   2007 Rnd 1 Pick 2  United States
# 3  Western All-Star Fan Vote Selection  2011 Rnd 1 Pick 15  United States
# 4  Western All-Star Fan Vote Selection   2012 Rnd 1 Pick 1  United States

# %%
df_drafts.head()
# Out:
#    Year  Rd1  Rd2   Rd3   Rd4   Rd5   Rd6   Rd7   Rd8   Rd9  Rd10
# 0  1984   24   23  23.0  23.0  23.0  23.0  23.0  22.0  22.0  22.0
# 1  1985   24   23  23.0  23.0  23.0  23.0  23.0   NaN   NaN   NaN
# 2  1986   24   23  23.0  23.0  23.0  23.0  23.0   NaN   NaN   NaN
# 3  1987   23   23  23.0  23.0  22.0  24.0  23.0   NaN   NaN   NaN
# 4  1988   25   25  25.0   NaN   NaN   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# ### Wrangling Drafts Data

# %%
# crosstabbing data

df_drafts_pivoted = pd.melt(df_drafts, id_vars = 'Year', var_name = 'Round', value_name = 'Pick')

df_drafts_pivoted.head()
# Out:
#    Year Round  Pick
# 0  1984   Rd1  24.0
# 1  1985   Rd1  24.0
# 2  1986   Rd1  24.0
# 3  1987   Rd1  23.0
# 4  1988   Rd1  25.0

# %%
# scaffolding based on pick

scaffold_list = []

for index, row in df_drafts_pivoted.iterrows():
    
    pick_num = 1
    
    while pick_num <= row['Pick']:
        
        new_row = row.copy()
        
        new_row['pick_num'] = pick_num
        
        scaffold_list.append(new_row)
        
        pick_num += 1

# %%
scaffold_list
# Out:
# [Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num       1
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num       2
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num       3
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num       4
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num       5
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num       6
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num       7
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num       8
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num       9
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      10
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      11
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      12
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      13
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      14
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      15
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      16
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      17
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      18
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      19
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      20
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      21
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      22
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      23
#  Name: 0, dtype: object,
#  Year        1984
#  Round        Rd1
#  Pick        24.0
#  pick_num      24
#  Name: 0, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num       1
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num       2
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num       3
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num       4
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num       5
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num       6
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num       7
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num       8
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num       9
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      10
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      11
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      12
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      13
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      14
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      15
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      16
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      17
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      18
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      19
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      20
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      21
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      22
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      23
#  Name: 1, dtype: object,
#  Year        1985
#  Round        Rd1
#  Pick        24.0
#  pick_num      24
#  Name: 1, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num       1
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num       2
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num       3
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num       4
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num       5
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num       6
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num       7
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num       8
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num       9
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      10
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      11
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      12
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      13
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      14
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      15
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      16
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      17
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      18
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      19
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      20
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      21
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      22
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      23
#  Name: 2, dtype: object,
#  Year        1986
#  Round        Rd1
#  Pick        24.0
#  pick_num      24
#  Name: 2, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num       1
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num       2
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num       3
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num       4
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num       5
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num       6
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num       7
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num       8
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num       9
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      10
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      11
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      12
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      13
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      14
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      15
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      16
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      17
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      18
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      19
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      20
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      21
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      22
#  Name: 3, dtype: object,
#  Year        1987
#  Round        Rd1
#  Pick        23.0
#  pick_num      23
#  Name: 3, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num       1
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num       2
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num       3
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num       4
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num       5
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num       6
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num       7
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num       8
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num       9
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      10
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      11
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      12
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      13
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      14
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      15
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      16
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      17
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      18
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      19
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      20
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      21
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      22
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      23
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      24
#  Name: 4, dtype: object,
#  Year        1988
#  Round        Rd1
#  Pick        25.0
#  pick_num      25
#  Name: 4, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num       1
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num       2
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num       3
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num       4
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num       5
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num       6
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num       7
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num       8
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num       9
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      10
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      11
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      12
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      13
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      14
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      15
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      16
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      17
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      18
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      19
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      20
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      21
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      22
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      23
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      24
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      25
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      26
#  Name: 5, dtype: object,
#  Year        1989
#  Round        Rd1
#  Pick        27.0
#  pick_num      27
#  Name: 5, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num       1
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num       2
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num       3
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num       4
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num       5
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num       6
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num       7
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num       8
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num       9
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      10
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      11
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      12
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      13
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      14
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      15
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      16
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      17
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      18
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      19
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      20
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      21
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      22
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      23
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      24
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      25
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      26
#  Name: 6, dtype: object,
#  Year        1990
#  Round        Rd1
#  Pick        27.0
#  pick_num      27
#  Name: 6, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num       1
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num       2
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num       3
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num       4
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num       5
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num       6
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num       7
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num       8
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num       9
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      10
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      11
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      12
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      13
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      14
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      15
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      16
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      17
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      18
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      19
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      20
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      21
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      22
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      23
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      24
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      25
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      26
#  Name: 7, dtype: object,
#  Year        1991
#  Round        Rd1
#  Pick        27.0
#  pick_num      27
#  Name: 7, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num       1
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num       2
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num       3
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num       4
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num       5
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num       6
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num       7
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num       8
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num       9
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      10
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      11
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      12
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      13
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      14
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      15
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      16
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      17
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      18
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      19
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      20
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      21
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      22
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      23
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      24
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      25
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      26
#  Name: 8, dtype: object,
#  Year        1992
#  Round        Rd1
#  Pick        27.0
#  pick_num      27
#  Name: 8, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num       1
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num       2
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num       3
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num       4
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num       5
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num       6
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num       7
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num       8
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num       9
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      10
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      11
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      12
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      13
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      14
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      15
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      16
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      17
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      18
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      19
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      20
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      21
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      22
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      23
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      24
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      25
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      26
#  Name: 9, dtype: object,
#  Year        1993
#  Round        Rd1
#  Pick        27.0
#  pick_num      27
#  Name: 9, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num       1
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num       2
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num       3
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num       4
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num       5
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num       6
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num       7
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num       8
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num       9
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      10
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      11
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      12
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      13
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      14
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      15
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      16
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      17
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      18
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      19
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      20
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      21
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      22
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      23
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      24
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      25
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      26
#  Name: 10, dtype: object,
#  Year        1994
#  Round        Rd1
#  Pick        27.0
#  pick_num      27
#  Name: 10, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num       1
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num       2
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num       3
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num       4
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num       5
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num       6
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num       7
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num       8
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num       9
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      10
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      11
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      12
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      13
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      14
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      15
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      16
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      17
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      18
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      19
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      20
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      21
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      22
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      23
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      24
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      25
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      26
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      27
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      28
#  Name: 11, dtype: object,
#  Year        1995
#  Round        Rd1
#  Pick        29.0
#  pick_num      29
#  Name: 11, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num       1
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num       2
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num       3
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num       4
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num       5
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num       6
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num       7
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num       8
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num       9
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      10
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      11
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      12
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      13
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      14
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      15
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      16
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      17
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      18
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      19
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      20
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      21
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      22
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      23
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      24
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      25
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      26
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      27
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      28
#  Name: 12, dtype: object,
#  Year        1996
#  Round        Rd1
#  Pick        29.0
#  pick_num      29
#  Name: 12, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num       1
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num       2
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num       3
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num       4
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num       5
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num       6
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num       7
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num       8
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num       9
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      10
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      11
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      12
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      13
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      14
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      15
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      16
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      17
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      18
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      19
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      20
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      21
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      22
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      23
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      24
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      25
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      26
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      27
#  Name: 13, dtype: object,
#  Year        1997
#  Round        Rd1
#  Pick        28.0
#  pick_num      28
#  Name: 13, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num       1
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num       2
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num       3
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num       4
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num       5
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num       6
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num       7
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num       8
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num       9
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      10
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      11
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      12
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      13
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      14
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      15
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      16
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      17
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      18
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      19
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      20
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      21
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      22
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      23
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      24
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      25
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      26
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      27
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      28
#  Name: 14, dtype: object,
#  Year        1998
#  Round        Rd1
#  Pick        29.0
#  pick_num      29
#  Name: 14, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num       1
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num       2
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num       3
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num       4
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num       5
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num       6
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num       7
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num       8
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num       9
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      10
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      11
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      12
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      13
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      14
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      15
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      16
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      17
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      18
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      19
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      20
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      21
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      22
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      23
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      24
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      25
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      26
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      27
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      28
#  Name: 15, dtype: object,
#  Year        1999
#  Round        Rd1
#  Pick        29.0
#  pick_num      29
#  Name: 15, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num       1
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num       2
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num       3
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num       4
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num       5
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num       6
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num       7
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num       8
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num       9
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      10
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      11
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      12
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      13
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      14
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      15
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      16
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      17
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      18
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      19
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      20
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      21
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      22
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      23
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      24
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      25
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      26
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      27
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      28
#  Name: 16, dtype: object,
#  Year        2000
#  Round        Rd1
#  Pick        29.0
#  pick_num      29
#  Name: 16, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num       1
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num       2
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num       3
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num       4
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num       5
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num       6
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num       7
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num       8
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num       9
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      10
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      11
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      12
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      13
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      14
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      15
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      16
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      17
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      18
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      19
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      20
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      21
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      22
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      23
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      24
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      25
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      26
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      27
#  Name: 17, dtype: object,
#  Year        2001
#  Round        Rd1
#  Pick        28.0
#  pick_num      28
#  Name: 17, dtype: object,
#  Year        2002
#  Round        Rd1
#  Pick        28.0
#  pick_num       1
#  Name: 18, dtype: object,
#  Year        2002
#  Round        Rd1
#  Pick        28.0
#  pick_num       2
#  Name: 18, dtype: object,
#  Year        2002
#  Round        Rd1
#  Pick        28.0
#  pick_num       3
#  Name: 18, dtype: object,
#  Year        2002
#  Round        Rd1
#  Pick        28.0
#  pick_num       4
#  Name: 18, dtype: object,
#  Year        2002
#  Round        Rd1
#  Pick        28.0
#  pick_num       5
#  Name: 18, dtype: object,
#  Year        2002
#  Round        Rd1
#  Pick        28.0
#  pick_num       6
#  Name: 18, dtype: object,
#  Year        2002
#  Round        Rd1
#  Pick        28.0
#  pick_num       7
#  Name: 18, dtype: object,
#  Year        2002
#  Round        Rd1
#  Pick        28.0
#  pick_num       8
#  Name: 18, dtype: object,
#  Year        2002
#  Round        Rd1
#  Pick        28.0
#  pick_num       9
#  Name: 18, dtype: object,
#  Year        2002
#  Round        Rd1
# ...
#  Year        2013
#  Round        Rd1
#  Pick        30.0
#  pick_num      29
#  Name: 29, dtype: object,
#  Year        2013
#  Round        Rd1
#  Pick        30.0
#  pick_num      30
#  Name: 29, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num       1
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num       2
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num       3
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num       4
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num       5
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num       6
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num       7
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num       8
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num       9
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      10
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      11
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      12
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      13
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      14
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      15
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      16
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      17
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      18
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      19
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      20
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      21
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      22
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      23
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      24
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      25
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      26
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      27
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      28
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      29
#  Name: 30, dtype: object,
#  Year        2014
#  Round        Rd1
#  Pick        30.0
#  pick_num      30
#  Name: 30, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num       1
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num       2
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num       3
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num       4
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num       5
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num       6
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num       7
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num       8
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num       9
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      10
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      11
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      12
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      13
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      14
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      15
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      16
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      17
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      18
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      19
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      20
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      21
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      22
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      23
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      24
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      25
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      26
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      27
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      28
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      29
#  Name: 31, dtype: object,
#  Year        2015
#  Round        Rd1
#  Pick        30.0
#  pick_num      30
#  Name: 31, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num       1
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num       2
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num       3
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num       4
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num       5
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num       6
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num       7
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num       8
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num       9
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      10
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      11
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      12
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      13
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      14
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      15
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      16
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      17
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      18
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      19
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      20
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      21
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      22
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      23
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      24
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      25
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      26
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      27
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      28
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      29
#  Name: 32, dtype: object,
#  Year        2016
#  Round        Rd1
#  Pick        30.0
#  pick_num      30
#  Name: 32, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num       1
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num       2
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num       3
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num       4
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num       5
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num       6
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num       7
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num       8
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num       9
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      10
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      11
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      12
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      13
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      14
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      15
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      16
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      17
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      18
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      19
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      20
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      21
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      22
#  Name: 33, dtype: object,
#  Year        1984
#  Round        Rd2
#  Pick        23.0
#  pick_num      23
#  Name: 33, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num       1
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num       2
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num       3
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num       4
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num       5
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num       6
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num       7
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num       8
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num       9
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      10
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      11
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      12
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      13
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      14
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      15
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      16
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      17
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      18
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      19
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      20
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      21
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      22
#  Name: 34, dtype: object,
#  Year        1985
#  Round        Rd2
#  Pick        23.0
#  pick_num      23
#  Name: 34, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num       1
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num       2
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num       3
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num       4
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num       5
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num       6
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num       7
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num       8
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num       9
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      10
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      11
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      12
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      13
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      14
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      15
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      16
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      17
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      18
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      19
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      20
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      21
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      22
#  Name: 35, dtype: object,
#  Year        1986
#  Round        Rd2
#  Pick        23.0
#  pick_num      23
#  Name: 35, dtype: object,
#  Year        1987
#  Round        Rd2
#  Pick        23.0
#  pick_num       1
#  Name: 36, dtype: object,
#  Year        1987
#  Round        Rd2
#  Pick        23.0
#  pick_num       2
#  Name: 36, dtype: object,
#  ...]

# %%
df_drafts_scaffolded = pd.DataFrame(scaffold_list)

df_drafts_scaffolded.head()
# Out:
#    Year Round  Pick  pick_num
# 0  1984   Rd1  24.0         1
# 0  1984   Rd1  24.0         2
# 0  1984   Rd1  24.0         3
# 0  1984   Rd1  24.0         4
# 0  1984   Rd1  24.0         5

# %%
# sorting

df_drafts_scaffolded.sort_values(by = ['Year', 'Round'], inplace = True)

# %%
# generating overall pick col per year

df_drafts_scaffolded['overall_pick'] = df_drafts_scaffolded.groupby('Year').cumcount()+1

df_drafts_scaffolded.head()
# Out:
#    Year Round  Pick  pick_num  overall_pick
# 0  1984   Rd1  24.0         1             1
# 0  1984   Rd1  24.0         2             2
# 0  1984   Rd1  24.0         3             3
# 0  1984   Rd1  24.0         4             4
# 0  1984   Rd1  24.0         5             5

# %%
# extracting round number from round

df_drafts_scaffolded['round_num'] = df_drafts_scaffolded['Round'].str.replace('Rd', '')

# %%
df_drafts_scaffolded.head()
# Out:
#    Year Round  Pick  pick_num  overall_pick round_num
# 0  1984   Rd1  24.0         1             1         1
# 0  1984   Rd1  24.0         2             2         1
# 0  1984   Rd1  24.0         3             3         1
# 0  1984   Rd1  24.0         4             4         1
# 0  1984   Rd1  24.0         5             5         1

# %%
df_drafts_scaffolded.tail()
# Out:
#     Year Round  Pick  pick_num  overall_pick round_num
# 65  2016   Rd2  30.0        26            56         2
# 65  2016   Rd2  30.0        27            57         2
# 65  2016   Rd2  30.0        28            58         2
# 65  2016   Rd2  30.0        29            59         2
# 65  2016   Rd2  30.0        30            60         2

# %% [markdown]
# ### Wrangling All Star Data

# %%
df_allstars.head()
# Out:
#    Year         Player Pos    HT   WT                   Team  \
# 0  2016  Stephen Curry   G   6-3  190  Golden State Warriors
# 1  2016   James Harden  SG   6-5  220        Houston Rockets
# 2  2016   Kevin Durant  SF   6-9  240  Golden State Warriors
# 3  2016  Kawhi Leonard   F   6-7  230      San Antonio Spurs
# 4  2016  Anthony Davis  PF  6-11  253   New Orleans Pelicans
#
#                         Selection Type    NBA Draft Status    Nationality
# 0  Western All-Star Fan Vote Selection   2009 Rnd 1 Pick 7  United States
# 1  Western All-Star Fan Vote Selection   2009 Rnd 1 Pick 3  United States
# 2  Western All-Star Fan Vote Selection   2007 Rnd 1 Pick 2  United States
# 3  Western All-Star Fan Vote Selection  2011 Rnd 1 Pick 15  United States
# 4  Western All-Star Fan Vote Selection   2012 Rnd 1 Pick 1  United States

# %%
# selecting relevant col

df_allstars_2 = df_allstars[['Year', 'Player', 'NBA Draft Status']]

df_allstars_2.head()
# Out:
#    Year         Player    NBA Draft Status
# 0  2016  Stephen Curry   2009 Rnd 1 Pick 7
# 1  2016   James Harden   2009 Rnd 1 Pick 3
# 2  2016   Kevin Durant   2007 Rnd 1 Pick 2
# 3  2016  Kawhi Leonard  2011 Rnd 1 Pick 15
# 4  2016  Anthony Davis   2012 Rnd 1 Pick 1

# %%
# filtering out where NBA draft status is undrafted

df_allstars_filtered = df_allstars_2[~df_allstars_2['NBA Draft Status'].str.contains('Undrafted')]

df_allstars_filtered.head()
# Out:
#    Year         Player    NBA Draft Status
# 0  2016  Stephen Curry   2009 Rnd 1 Pick 7
# 1  2016   James Harden   2009 Rnd 1 Pick 3
# 2  2016   Kevin Durant   2007 Rnd 1 Pick 2
# 3  2016  Kawhi Leonard  2011 Rnd 1 Pick 15
# 4  2016  Anthony Davis   2012 Rnd 1 Pick 1

# %%
# parsing pick year, round, and pick from draft status

df_allstars_filtered['parse'] = df_allstars_filtered['NBA Draft Status'].apply(lambda x: pd.Series(re.findall(r'(\d{4})\sRnd\s(\d+)\sPick\s(\d+)', x)))
# Out:
# C:\Users\CharlesYi\AppData\Local\Temp\ipykernel_46236\3942621186.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_allstars_filtered['parse'] = df_allstars_filtered['NBA Draft Status'].apply(lambda x: pd.Series(re.findall(r'(\d{4})\sRnd\s(\d+)\sPick\s(\d+)', x)))

# %%
df_allstars_filtered
# Out:
#      Year           Player    NBA Draft Status          parse
# 0    2016    Stephen Curry   2009 Rnd 1 Pick 7   (2009, 1, 7)
# 1    2016     James Harden   2009 Rnd 1 Pick 3   (2009, 1, 3)
# 2    2016     Kevin Durant   2007 Rnd 1 Pick 2   (2007, 1, 2)
# 3    2016    Kawhi Leonard  2011 Rnd 1 Pick 15  (2011, 1, 15)
# 4    2016    Anthony Davis   2012 Rnd 1 Pick 1   (2012, 1, 1)
# ..    ...              ...                 ...            ...
# 434  2000  Antonio McDyess   1995 Rnd 1 Pick 2   (1995, 1, 2)
# 435  2000      Gary Payton   1990 Rnd 1 Pick 2   (1990, 1, 2)
# 436  2000  Rasheed Wallace   1995 Rnd 1 Pick 4   (1995, 1, 4)
# 437  2000   David Robinson   1987 Rnd 1 Pick 1   (1987, 1, 1)
# 438  2000      Vlade Divac  1989 Rnd 1 Pick 26  (1989, 1, 26)
#
# [433 rows x 4 columns]

# %%
df_allstars_filtered[['pick_year', 'round', 'pick']] = pd.DataFrame(df_allstars_filtered['parse'].to_list(), index=df_allstars_filtered.index)

"""note: When you pass the result of to_list() (which is a list of tuples or lists) to pd.DataFrame(), 
pandas automatically converts each tuple/list into a separate row. 
The number of elements within each tuple/list determines how many columns will be created."""
# Out:
# C:\Users\CharlesYi\AppData\Local\Temp\ipykernel_46236\3063178635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_allstars_filtered[['pick_year', 'round', 'pick']] = pd.DataFrame(df_allstars_filtered['parse'].to_list(), index=df_allstars_filtered.index)
# C:\Users\CharlesYi\AppData\Local\Temp\ipykernel_46236\3063178635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_allstars_filtered[['pick_year', 'round', 'pick']] = pd.DataFrame(df_allstars_filtered['parse'].to_list(), index=df_allstars_filtered.index)
# C:\Users\CharlesYi\AppData\Local\Temp\ipykernel_46236\3063178635.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_allstars_filtered[['pick_year', 'round', 'pick']] = pd.DataFrame(df_allstars_filtered['parse'].to_list(), index=df_allstars_filtered.index)
# 'note: When you pass the result of to_list() (which is a list of tuples or lists) to pd.DataFrame(), \npandas automatically converts each tuple/list into a separate row. \nThe number of elements within each tuple/list determines how many columns will be created.'

# %%
df_allstars_filtered
# Out:
#      Year           Player    NBA Draft Status          parse pick_year round  \
# 0    2016    Stephen Curry   2009 Rnd 1 Pick 7   (2009, 1, 7)      2009     1
# 1    2016     James Harden   2009 Rnd 1 Pick 3   (2009, 1, 3)      2009     1
# 2    2016     Kevin Durant   2007 Rnd 1 Pick 2   (2007, 1, 2)      2007     1
# 3    2016    Kawhi Leonard  2011 Rnd 1 Pick 15  (2011, 1, 15)      2011     1
# 4    2016    Anthony Davis   2012 Rnd 1 Pick 1   (2012, 1, 1)      2012     1
# ..    ...              ...                 ...            ...       ...   ...
# 434  2000  Antonio McDyess   1995 Rnd 1 Pick 2   (1995, 1, 2)      1995     1
# 435  2000      Gary Payton   1990 Rnd 1 Pick 2   (1990, 1, 2)      1990     1
# 436  2000  Rasheed Wallace   1995 Rnd 1 Pick 4   (1995, 1, 4)      1995     1
# 437  2000   David Robinson   1987 Rnd 1 Pick 1   (1987, 1, 1)      1987     1
# 438  2000      Vlade Divac  1989 Rnd 1 Pick 26  (1989, 1, 26)      1989     1
#
#     pick
# 0      7
# 1      3
# 2      2
# 3     15
# 4      1
# ..   ...
# 434    2
# 435    2
# 436    4
# 437    1
# 438   26
#
# [433 rows x 7 columns]

# %%
# another way of doing it

df_allstars_filtered['parse'].apply(lambda x: pd.Series(x))
# Out:
#         0  1   2
# 0    2009  1   7
# 1    2009  1   3
# 2    2007  1   2
# 3    2011  1  15
# 4    2012  1   1
# ..    ... ..  ..
# 434  1995  1   2
# 435  1990  1   2
# 436  1995  1   4
# 437  1987  1   1
# 438  1989  1  26
#
# [433 rows x 3 columns]

# %% [markdown]
# ### Bringing It Together

# %%
# changing data types

df_allstars_filtered['pick_year'] = df_allstars_filtered['pick_year'].astype('int64')
# Out:
# C:\Users\CharlesYi\AppData\Local\Temp\ipykernel_46236\1376180628.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_allstars_filtered['pick_year'] = df_allstars_filtered['pick_year'].astype('int64')

# %%
# changing data types

df_allstars_filtered['pick'] = df_allstars_filtered['pick'].astype('int64')
# Out:
# C:\Users\CharlesYi\AppData\Local\Temp\ipykernel_46236\1036656989.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_allstars_filtered['pick'] = df_allstars_filtered['pick'].astype('int64')

# %%
df_allstars_filtered.dtypes
# Out:
# Year                 int64
# Player              object
# NBA Draft Status    object
# parse               object
# pick_year            int64
# round               object
# pick                 int64
# dtype: object

# %%
df_drafts_scaffolded.dtypes
# Out:
# Year              int64
# Round            object
# Pick            float64
# pick_num          int64
# overall_pick      int64
# round_num        object
# dtype: object

# %%
df_merge = df_allstars_filtered.merge(df_drafts_scaffolded, left_on = ['pick_year', 'round', 'pick'], right_on = ['Year', 'round_num', 'pick_num'])

df_merge
# Out:
#      Year_x           Player    NBA Draft Status          parse  pick_year  \
# 0      2016    Stephen Curry   2009 Rnd 1 Pick 7   (2009, 1, 7)       2009
# 1      2015    Stephen Curry   2009 Rnd 1 Pick 7   (2009, 1, 7)       2009
# 2      2014    Stephen Curry   2009 Rnd 1 Pick 7   (2009, 1, 7)       2009
# 3      2013    Stephen Curry   2009 Rnd 1 Pick 7   (2009, 1, 7)       2009
# 4      2016     James Harden   2009 Rnd 1 Pick 3   (2009, 1, 3)       2009
# ..      ...              ...                 ...            ...        ...
# 428    2000    Allan Houston  1993 Rnd 1 Pick 11  (1993, 1, 11)       1993
# 429    2000   Michael Finley  1995 Rnd 1 Pick 21  (1995, 1, 21)       1995
# 430    2000  Antonio McDyess   1995 Rnd 1 Pick 2   (1995, 1, 2)       1995
# 431    2000   David Robinson   1987 Rnd 1 Pick 1   (1987, 1, 1)       1987
# 432    2000      Vlade Divac  1989 Rnd 1 Pick 26  (1989, 1, 26)       1989
#
#     round  pick  Year_y Round  Pick  pick_num  overall_pick round_num
# 0       1     7    2009   Rd1  30.0         7             7         1
# 1       1     7    2009   Rd1  30.0         7             7         1
# 2       1     7    2009   Rd1  30.0         7             7         1
# 3       1     7    2009   Rd1  30.0         7             7         1
# 4       1     3    2009   Rd1  30.0         3             3         1
# ..    ...   ...     ...   ...   ...       ...           ...       ...
# 428     1    11    1993   Rd1  27.0        11            11         1
# 429     1    21    1995   Rd1  29.0        21            21         1
# 430     1     2    1995   Rd1  29.0         2             2         1
# 431     1     1    1987   Rd1  23.0         1             1         1
# 432     1    26    1989   Rd1  27.0        26            26         1
#
# [433 rows x 13 columns]

# %%
# aggregating

df_agg = df_merge.groupby(['Player', 'NBA Draft Status']).agg(overall_pick = ('overall_pick', 'max'))

df_agg
# Out:
#                                        overall_pick
# Player             NBA Draft Status
# Al Horford         2007 Rnd 1 Pick 3              3
# Allan Houston      1993 Rnd 1 Pick 11            11
# Allen Iverson      1996 Rnd 1 Pick 1              1
# Alonzo Mourning    1992 Rnd 1 Pick 2              2
# Amar'e Stoudemire  2002 Rnd 1 Pick 9              9
# ...                                             ...
# Vlade Divac        1989 Rnd 1 Pick 26            26
# Wally Szczerbiak   1999 Rnd 1 Pick 6              6
# Yao Ming           2002 Rnd 1 Pick 1              1
# Zach Randolph      2001 Rnd 1 Pick 19            19
# Zydrunas Ilgauskas 1996 Rnd 1 Pick 20            20
#
# [121 rows x 1 columns]

# %%
df_agg.shape
# Out:
# (121, 1)

# %%
# selecting top three overall picks

df_agg.nlargest(3, 'overall_pick')
# Out:
#                                   overall_pick
# Player        NBA Draft Status
# Isaiah Thomas 2011 Rnd 2 Pick 30            60
# Manu Ginobili 1999 Rnd 2 Pick 28            57
# Anthony Mason 1988 Rnd 3 Pick 3             53
