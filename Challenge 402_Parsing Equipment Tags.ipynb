# %%
# importing libraries

import pandas as pd

import numpy as np

import re

# %%
# creating data dict

df_dict = {'tag' : ['P101A/B/C', 'P203A-D', 'P401A/G', 'T101B', 'B301'],
          'Service' : ['Oil', 'Gas', 'N2', 'FW', 'CW'],
          'WorkingTemp' : ['35', '41', '10', '40', '23'],
          'WorkingPressure' : ['2000', '3000', '2100', '1500', '2400']}

# %%
# turning dict into df

df = pd.DataFrame(df_dict)

df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure
# 0  P101A/B/C     Oil          35            2000
# 1    P203A-D     Gas          41            3000
# 2    P401A/G      N2          10            2100
# 3      T101B      FW          40            1500
# 4       B301      CW          23            2400

# %%
# splitting tag

parse = df['tag'].apply(lambda x: (re.findall(r'([A-Z]\d{3})(.+)*', x)))

# %%
# adding tuple as column

df['parse_tuple'] = parse

df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]

# %%
# splitting the parse tuple into separate columns

# first, converting tuple into list

df['parse_list'] = df['parse_tuple'].apply(lambda x: list(x[0])) # if isinstance(x, list) and isinstance(x[0], tuple) else x)

# %%
df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple  \
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]
#
#       parse_list
# 0  [P101, A/B/C]
# 1    [P203, A-D]
# 2    [P401, A/G]
# 3      [T101, B]
# 4       [B301, ]

# %%
df['parse_list'].apply(type) # parse_list is a list
# Out:
# 0    <class 'list'>
# 1    <class 'list'>
# 2    <class 'list'>
# 3    <class 'list'>
# 4    <class 'list'>
# Name: parse_list, dtype: object

# %%
# checking to make sure tuple element within list became strings

df['parse_list'].apply(lambda x: [type(i) for i in x])
# Out:
# 0    [<class 'str'>, <class 'str'>]
# 1    [<class 'str'>, <class 'str'>]
# 2    [<class 'str'>, <class 'str'>]
# 3    [<class 'str'>, <class 'str'>]
# 4    [<class 'str'>, <class 'str'>]
# Name: parse_list, dtype: object

# %%
# parsing letter tag from parse_list

def letter_tag (col):

    parse = []
    
    for x,y in col:
        
        if y is None:
            parse.append(pd.NA)
        else:
            parse.append(y)
            
    return parse

# %%
# applying function

df['letter_tag'] = letter_tag(df['parse_list'])

# %%
df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple  \
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]
#
#       parse_list letter_tag
# 0  [P101, A/B/C]      A/B/C
# 1    [P203, A-D]        A-D
# 2    [P401, A/G]        A/G
# 3      [T101, B]          B
# 4       [B301, ]

# %% [markdown]
# ### GK suggestion - looping over parse tuple to extract letter and main tags without converting it first to a list

# %%
df['parse_tuple'].apply(type)
# Out:
# 0    <class 'list'>
# 1    <class 'list'>
# 2    <class 'list'>
# 3    <class 'list'>
# 4    <class 'list'>
# Name: parse_tuple, dtype: object

# %%
df['parse_tuple'].apply(lambda x: [type(i) for i in x])
# Out:
# 0    [<class 'tuple'>]
# 1    [<class 'tuple'>]
# 2    [<class 'tuple'>]
# 3    [<class 'tuple'>]
# 4    [<class 'tuple'>]
# Name: parse_tuple, dtype: object

# %%
df_gk = df.copy()

# %%
# trying to create mutiple tuples to test

parse_tuple_test = [[('A', 'B'), (1, 2)],
                    [('C', 'D'), (3, 4)],
                    [('E', 'F'), (5, 6)],
                    [('G', 'H'), (7, 8)],
                    [('I', 'J'), (9, 10)]]

df_gk['parse_tuple_test'] = parse_tuple_test

df_gk.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple  \
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]
#
#       parse_list letter_tag   parse_tuple_test
# 0  [P101, A/B/C]      A/B/C   [(A, B), (1, 2)]
# 1    [P203, A-D]        A-D   [(C, D), (3, 4)]
# 2    [P401, A/G]        A/G   [(E, F), (5, 6)]
# 3      [T101, B]          B   [(G, H), (7, 8)]
# 4       [B301, ]             [(I, J), (9, 10)]

# %%
df_gk['parse_tuple_test'].apply(type)
# Out:
# 0    <class 'list'>
# 1    <class 'list'>
# 2    <class 'list'>
# 3    <class 'list'>
# 4    <class 'list'>
# Name: parse_tuple_test, dtype: object

# %%
df_gk['parse_tuple_test'].apply(lambda x: [type(i) for i in x])
# Out:
# 0    [<class 'tuple'>, <class 'tuple'>]
# 1    [<class 'tuple'>, <class 'tuple'>]
# 2    [<class 'tuple'>, <class 'tuple'>]
# 3    [<class 'tuple'>, <class 'tuple'>]
# 4    [<class 'tuple'>, <class 'tuple'>]
# Name: parse_tuple_test, dtype: object

# %%
# test 1

def parse_loop_func(row):

    parse_loop_list = []
    
    for list_ in row:
        
        list_ = list(list_)

        parse_loop_list.append(list_)
    
    print(parse_loop_list)
    
    return parse_loop_list

# %%
df_gk['parse_tuple_test'].apply(lambda x: pd.Series((parse_loop_func(x)))) # applying func using lambda with pd.Series to split into col
# Out:
# [['A', 'B'], [1, 2]]
# [['C', 'D'], [3, 4]]
# [['E', 'F'], [5, 6]]
# [['G', 'H'], [7, 8]]
# [['I', 'J'], [9, 10]]
#         0        1
# 0  [A, B]   [1, 2]
# 1  [C, D]   [3, 4]
# 2  [E, F]   [5, 6]
# 3  [G, H]   [7, 8]
# 4  [I, J]  [9, 10]

# %%
test = [['A', 'B'], [1, 2]]

# %%
pd.DataFrame(pd.Series(test)) # pd.series vertical, as opposed to horizontal when used in the context of apply
# Out:
#         0
# 0  [A, B]
# 1  [1, 2]

# %% [markdown]
# ### End GK Solution

# %%
# parsing main tag

def main_tag (col):
    
    parse = []
    
    for x,y in col:
        
        if x is None:
            return parse.append(pd.NA)
        
        else:
            parse.append(x)
    
    return parse

# %%
# applying function

df['main_tag'] = main_tag(df['parse_list'])

# %%
df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple  \
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]
#
#       parse_list letter_tag main_tag
# 0  [P101, A/B/C]      A/B/C     P101
# 1    [P203, A-D]        A-D     P203
# 2    [P401, A/G]        A/G     P401
# 3      [T101, B]          B     T101
# 4       [B301, ]                B301

# %%
# extracting first letter

df['first_letter'] = df['letter_tag'].apply(lambda x: re.findall(r'(^[^/-])', x))

# %%
df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple  \
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]
#
#       parse_list letter_tag main_tag first_letter
# 0  [P101, A/B/C]      A/B/C     P101          [A]
# 1    [P203, A-D]        A-D     P203          [A]
# 2    [P401, A/G]        A/G     P401          [A]
# 3      [T101, B]          B     T101          [B]
# 4       [B301, ]                B301           []

# %%
df['first_letter'].apply(type)
# Out:
# 0    <class 'list'>
# 1    <class 'list'>
# 2    <class 'list'>
# 3    <class 'list'>
# 4    <class 'list'>
# Name: first_letter, dtype: object

# %%
df['first_letter'].apply(lambda x: [type(i) for i in x ])
# Out:
# 0    [<class 'str'>]
# 1    [<class 'str'>]
# 2    [<class 'str'>]
# 3    [<class 'str'>]
# 4                 []
# Name: first_letter, dtype: object

# %%
# creating function to convert back into list

def list_conversion(col):
    
    converted = []
    
    for x in col:
        
        if x:
            converted.append(x[0])
        else:
            converted.append(None)
            
    return converted

# %%
# applying function

df['first_letter'] = list_conversion(df['first_letter'])

# %%
df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple  \
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]
#
#       parse_list letter_tag main_tag first_letter last_letter  \
# 0  [P101, A/B/C]      A/B/C     P101            A           C
# 1    [P203, A-D]        A-D     P203            A           D
# 2    [P401, A/G]        A/G     P401            A           G
# 3      [T101, B]          B     T101            B           B
# 4       [B301, ]                B301         None        None
#
#    first_letter_int  last_letter_int
# 0              65.0             67.0
# 1              65.0             68.0
# 2              65.0             71.0
# 3              66.0             66.0
# 4               NaN              NaN

# %%
# extracting last letter

df['last_letter'] = df['letter_tag'].apply(lambda x: re.findall(r'([^/-]$)', x))

# %%
df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple  \
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]
#
#       parse_list letter_tag main_tag first_letter last_letter
# 0  [P101, A/B/C]      A/B/C     P101            A         [C]
# 1    [P203, A-D]        A-D     P203            A         [D]
# 2    [P401, A/G]        A/G     P401            A         [G]
# 3      [T101, B]          B     T101            B         [B]
# 4       [B301, ]                B301         None          []

# %%
# applying list conversion

df['last_letter'] = list_conversion(df['last_letter'])

# %%
df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple  \
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]
#
#       parse_list letter_tag main_tag first_letter last_letter
# 0  [P101, A/B/C]      A/B/C     P101            A           C
# 1    [P203, A-D]        A-D     P203            A           D
# 2    [P401, A/G]        A/G     P401            A           G
# 3      [T101, B]          B     T101            B           B
# 4       [B301, ]                B301         None        None

# %%
# converting first letter to int

df['first_letter_int'] = df['first_letter'].apply(lambda x: None if x == None else ord(x))

# converting last letter to int

df['last_letter_int'] = df['last_letter'].apply(lambda x: None if x == None else ord(x))

# %%
df.head()
# Out:
#          tag Service WorkingTemp WorkingPressure      parse_tuple  \
# 0  P101A/B/C     Oil          35            2000  [(P101, A/B/C)]
# 1    P203A-D     Gas          41            3000    [(P203, A-D)]
# 2    P401A/G      N2          10            2100    [(P401, A/G)]
# 3      T101B      FW          40            1500      [(T101, B)]
# 4       B301      CW          23            2400       [(B301, )]
#
#       parse_list letter_tag main_tag first_letter last_letter  \
# 0  [P101, A/B/C]      A/B/C     P101            A           C
# 1    [P203, A-D]        A-D     P203            A           D
# 2    [P401, A/G]        A/G     P401            A           G
# 3      [T101, B]          B     T101            B           B
# 4       [B301, ]                B301         None        None
#
#    first_letter_int  last_letter_int
# 0              65.0             67.0
# 1              65.0             68.0
# 2              65.0             71.0
# 3              66.0             66.0
# 4               NaN              NaN

# %%
# cleaning up columns

df_clean = df[['tag', 'Service', 'WorkingTemp', 'WorkingPressure', 'main_tag', 'first_letter_int', 'last_letter_int']]
    
df_clean.head()
# Out:
#          tag Service WorkingTemp WorkingPressure main_tag  first_letter_int  \
# 0  P101A/B/C     Oil          35            2000     P101              65.0
# 1    P203A-D     Gas          41            3000     P203              65.0
# 2    P401A/G      N2          10            2100     P401              65.0
# 3      T101B      FW          40            1500     T101              66.0
# 4       B301      CW          23            2400     B301               NaN
#
#    last_letter_int
# 0             67.0
# 1             68.0
# 2             71.0
# 3             66.0
# 4              NaN

# %%
df_clean
# Out:
#          tag Service WorkingTemp WorkingPressure main_tag  first_letter_int  \
# 0  P101A/B/C     Oil          35            2000     P101              65.0
# 1    P203A-D     Gas          41            3000     P203              65.0
# 2    P401A/G      N2          10            2100     P401              65.0
# 3      T101B      FW          40            1500     T101              66.0
# 4       B301      CW          23            2400     B301               NaN
#
#    last_letter_int
# 0             67.0
# 1             68.0
# 2             71.0
# 3             66.0
# 4              NaN

# %%
# scaffolding based on first and last letter

new_rows = []

for index, row in df_clean.iterrows():
    
    init = row['first_letter_int']
    end = row['last_letter_int']
    
    if not pd.isna(init):

        while init <= end:
        
            increment = init
        
            new_row = row.copy()
        
            new_row['scaffold'] = increment 
        
            new_rows.append(new_row)
        
            init += 1
    
    else:
        
        new_row = row.copy()
        
        new_row['scaffold'] = None
        
        new_rows.append(new_row)

# %%
new_rows
# Out:
# [tag                 P101A/B/C
#  Service                   Oil
#  WorkingTemp                35
#  WorkingPressure          2000
#  main_tag                 P101
#  first_letter_int         65.0
#  last_letter_int          67.0
#  scaffold                 65.0
#  Name: 0, dtype: object,
#  tag                 P101A/B/C
#  Service                   Oil
#  WorkingTemp                35
#  WorkingPressure          2000
#  main_tag                 P101
#  first_letter_int         65.0
#  last_letter_int          67.0
#  scaffold                 66.0
#  Name: 0, dtype: object,
#  tag                 P101A/B/C
#  Service                   Oil
#  WorkingTemp                35
#  WorkingPressure          2000
#  main_tag                 P101
#  first_letter_int         65.0
#  last_letter_int          67.0
#  scaffold                 67.0
#  Name: 0, dtype: object,
#  tag                 P203A-D
#  Service                 Gas
#  WorkingTemp              41
#  WorkingPressure        3000
#  main_tag               P203
#  first_letter_int       65.0
#  last_letter_int        68.0
#  scaffold               65.0
#  Name: 1, dtype: object,
#  tag                 P203A-D
#  Service                 Gas
#  WorkingTemp              41
#  WorkingPressure        3000
#  main_tag               P203
#  first_letter_int       65.0
#  last_letter_int        68.0
#  scaffold               66.0
#  Name: 1, dtype: object,
#  tag                 P203A-D
#  Service                 Gas
#  WorkingTemp              41
#  WorkingPressure        3000
#  main_tag               P203
#  first_letter_int       65.0
#  last_letter_int        68.0
#  scaffold               67.0
#  Name: 1, dtype: object,
#  tag                 P203A-D
#  Service                 Gas
#  WorkingTemp              41
#  WorkingPressure        3000
#  main_tag               P203
#  first_letter_int       65.0
#  last_letter_int        68.0
#  scaffold               68.0
#  Name: 1, dtype: object,
#  tag                 P401A/G
#  Service                  N2
#  WorkingTemp              10
#  WorkingPressure        2100
#  main_tag               P401
#  first_letter_int       65.0
#  last_letter_int        71.0
#  scaffold               65.0
#  Name: 2, dtype: object,
#  tag                 P401A/G
#  Service                  N2
#  WorkingTemp              10
#  WorkingPressure        2100
#  main_tag               P401
#  first_letter_int       65.0
#  last_letter_int        71.0
#  scaffold               66.0
#  Name: 2, dtype: object,
#  tag                 P401A/G
#  Service                  N2
#  WorkingTemp              10
#  WorkingPressure        2100
#  main_tag               P401
#  first_letter_int       65.0
#  last_letter_int        71.0
#  scaffold               67.0
#  Name: 2, dtype: object,
#  tag                 P401A/G
#  Service                  N2
#  WorkingTemp              10
#  WorkingPressure        2100
#  main_tag               P401
#  first_letter_int       65.0
#  last_letter_int        71.0
#  scaffold               68.0
#  Name: 2, dtype: object,
#  tag                 P401A/G
#  Service                  N2
#  WorkingTemp              10
#  WorkingPressure        2100
#  main_tag               P401
#  first_letter_int       65.0
#  last_letter_int        71.0
#  scaffold               69.0
#  Name: 2, dtype: object,
#  tag                 P401A/G
#  Service                  N2
#  WorkingTemp              10
#  WorkingPressure        2100
#  main_tag               P401
#  first_letter_int       65.0
#  last_letter_int        71.0
#  scaffold               70.0
#  Name: 2, dtype: object,
#  tag                 P401A/G
#  Service                  N2
#  WorkingTemp              10
#  WorkingPressure        2100
#  main_tag               P401
#  first_letter_int       65.0
#  last_letter_int        71.0
#  scaffold               71.0
#  Name: 2, dtype: object,
#  tag                 T101B
#  Service                FW
#  WorkingTemp            40
#  WorkingPressure      1500
#  main_tag             T101
#  first_letter_int     66.0
#  last_letter_int      66.0
#  scaffold             66.0
#  Name: 3, dtype: object,
#  tag                 B301
#  Service               CW
#  WorkingTemp           23
#  WorkingPressure     2400
#  main_tag            B301
#  first_letter_int     NaN
#  last_letter_int      NaN
#  scaffold            None
#  Name: 4, dtype: object]

# %%
# converting scaffold into df

df_scaffold = pd.DataFrame(new_rows)

df_scaffold.reset_index(inplace = True)

df_scaffold
# Out:
#     index        tag Service WorkingTemp WorkingPressure main_tag  \
# 0       0  P101A/B/C     Oil          35            2000     P101
# 1       0  P101A/B/C     Oil          35            2000     P101
# 2       0  P101A/B/C     Oil          35            2000     P101
# 3       1    P203A-D     Gas          41            3000     P203
# 4       1    P203A-D     Gas          41            3000     P203
# 5       1    P203A-D     Gas          41            3000     P203
# 6       1    P203A-D     Gas          41            3000     P203
# 7       2    P401A/G      N2          10            2100     P401
# 8       2    P401A/G      N2          10            2100     P401
# 9       2    P401A/G      N2          10            2100     P401
# 10      2    P401A/G      N2          10            2100     P401
# 11      2    P401A/G      N2          10            2100     P401
# 12      2    P401A/G      N2          10            2100     P401
# 13      2    P401A/G      N2          10            2100     P401
# 14      3      T101B      FW          40            1500     T101
# 15      4       B301      CW          23            2400     B301
#
#     first_letter_int  last_letter_int  scaffold
# 0               65.0             67.0      65.0
# 1               65.0             67.0      66.0
# 2               65.0             67.0      67.0
# 3               65.0             68.0      65.0
# 4               65.0             68.0      66.0
# 5               65.0             68.0      67.0
# 6               65.0             68.0      68.0
# 7               65.0             71.0      65.0
# 8               65.0             71.0      66.0
# 9               65.0             71.0      67.0
# 10              65.0             71.0      68.0
# 11              65.0             71.0      69.0
# 12              65.0             71.0      70.0
# 13              65.0             71.0      71.0
# 14              66.0             66.0      66.0
# 15               NaN              NaN       NaN

# %%
# converting scaffolded to letters

df_scaffold['scaffold_letters'] = df_scaffold['scaffold'].apply(lambda x: chr(int(x)) if not pd.isna(x) else None)

df_scaffold.head()
# Out:
#    index        tag Service WorkingTemp WorkingPressure main_tag  \
# 0      0  P101A/B/C     Oil          35            2000     P101
# 1      0  P101A/B/C     Oil          35            2000     P101
# 2      0  P101A/B/C     Oil          35            2000     P101
# 3      1    P203A-D     Gas          41            3000     P203
# 4      1    P203A-D     Gas          41            3000     P203
#
#    first_letter_int  last_letter_int  scaffold scaffold_letters
# 0              65.0             67.0      65.0                A
# 1              65.0             67.0      66.0                B
# 2              65.0             67.0      67.0                C
# 3              65.0             68.0      65.0                A
# 4              65.0             68.0      66.0                B

# %%
# creating new tag

df_scaffold['new_tag'] = df_scaffold.apply(lambda x: x['main_tag'] + x['scaffold_letters'] if not pd.isna(x['scaffold_letters']) else x['tag'], axis = 1)

df_scaffold
# Out:
#     index        tag Service WorkingTemp WorkingPressure main_tag  \
# 0       0  P101A/B/C     Oil          35            2000     P101
# 1       0  P101A/B/C     Oil          35            2000     P101
# 2       0  P101A/B/C     Oil          35            2000     P101
# 3       1    P203A-D     Gas          41            3000     P203
# 4       1    P203A-D     Gas          41            3000     P203
# 5       1    P203A-D     Gas          41            3000     P203
# 6       1    P203A-D     Gas          41            3000     P203
# 7       2    P401A/G      N2          10            2100     P401
# 8       2    P401A/G      N2          10            2100     P401
# 9       2    P401A/G      N2          10            2100     P401
# 10      2    P401A/G      N2          10            2100     P401
# 11      2    P401A/G      N2          10            2100     P401
# 12      2    P401A/G      N2          10            2100     P401
# 13      2    P401A/G      N2          10            2100     P401
# 14      3      T101B      FW          40            1500     T101
# 15      4       B301      CW          23            2400     B301
#
#     first_letter_int  last_letter_int  scaffold scaffold_letters new_tag
# 0               65.0             67.0      65.0                A   P101A
# 1               65.0             67.0      66.0                B   P101B
# 2               65.0             67.0      67.0                C   P101C
# 3               65.0             68.0      65.0                A   P203A
# 4               65.0             68.0      66.0                B   P203B
# 5               65.0             68.0      67.0                C   P203C
# 6               65.0             68.0      68.0                D   P203D
# 7               65.0             71.0      65.0                A   P401A
# 8               65.0             71.0      66.0                B   P401B
# 9               65.0             71.0      67.0                C   P401C
# 10              65.0             71.0      68.0                D   P401D
# 11              65.0             71.0      69.0                E   P401E
# 12              65.0             71.0      70.0                F   P401F
# 13              65.0             71.0      71.0                G   P401G
# 14              66.0             66.0      66.0                B   T101B
# 15               NaN              NaN       NaN             None    B301
